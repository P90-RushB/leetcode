# %%
from PIL import Image
import numpy as np

# %%
a = Image.open(r'D:\AI\my.jpg')

# %%
aa = np.array(a)

# %%
aa.shape
# Out:
# (331, 322, 4)

# %%
b = a.convert('RGB')

# %%
bb = np.array(b)

# %%
bb.shape
# Out:
# (331, 322, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(bb)
