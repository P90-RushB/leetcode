# %%
# %matplotlib notebook
import numpy as np

# %%
path = r'F:\other\697\S000000_H00_C00_D00_INFO.CSV'

# %%
info = np.genfromtxt(path, delimiter=',',autostrip=True,dtype=str)[:,:-1].astype(float)

# %%
info.shape
# Out:
# (97222, 12)

# %%
info[:,0]
# Out:
# array([0.0000e+00, 1.0000e+00, 2.0000e+00, ..., 9.7219e+04, 9.7220e+04,
#        9.7221e+04])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(info[:,2])
# Out:
# <img src="data:image/png;base64,..." width="913.3333575284046">
